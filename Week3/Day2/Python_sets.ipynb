# %% [markdown]
# # Set

# %%
id = {1,2,3,4,5,6,7,7,8,8,9}

# %%
print(id)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# # Access in set

# %%
for i in id:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
min(id)
# Out:
# 1

# %%
max(id)
# Out:
# 9

# %%
d = {101,102,103,104,101,103}

# %% [markdown]
# # Empty set in python

# %%
# create an empty set
empty_set = set()

# create an empty dictionary
empty_dictionary = { }

# check data type of empty_set
print('Data type of empty_set:', type(empty_set))

# check data type of dictionary_set
print('Data type of empty_dictionary:', type(empty_dictionary))
# Out:
# Data type of empty_set: <class 'set'>
# Data type of empty_dictionary: <class 'dict'>

# %% [markdown]
# # Duplicate items in a set

# %%
e = {1,2,3,4,5,6,7}
print(e)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# # Adding a set in python

# %%
e = {1,2,3,4,5,6,7}
print("The numbers are :",e)
e.add(32)
print("The updated set is :",e)
# Out:
# The numbers are : {1, 2, 3, 4, 5, 6, 7}
# The updated set is : {32, 1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# # Update set in python

# %%
companies = {'Lacoste', 'Ralph Lauren'}
tech_companies = ['apple', 'google', 'apple']

# using update() method
companies.update(tech_companies)

print(companies)

# Output: {'google', 'apple', 'Lacoste', 'Ralph Lauren'}
# Out:
# {'Ralph Lauren', 'google', 'Lacoste', 'apple'}

# %% [markdown]
# # Remove element from set

# %%
languages = {'Swift', 'Java', 'Python'}

print('Initial Set:',languages)

# remove 'Java' from a set
removedValue = languages.discard('Java')

print('Set after remove():', languages)
# Out:
# Initial Set: {'Java', 'Python', 'Swift'}
# Set after remove(): {'Python', 'Swift'}

# %% [markdown]
# # Iteration over set in python

# %%
fruits = {"Apple", "Peach", "Mango"}

# for loop to access each fruits
for fruit in fruits: 
    print(fruit)
# Out:
# Mango
# Apple
# Peach

# %% [markdown]
# # Number of set in element

# %%
number = {2,4,6,8}
print('Set:',number)

# find number of elements
print('Total Elements:', len(number))
# Out:
# Set: {8, 2, 4, 6}
# Total Elements: 4

# %% [markdown]
# # UNION IN PYTHON

# %%
# first set
A = {1, 3, 5}

# second set
B = {0, 2, 4}

# perform union operation using |
print('Union using |:', A | B)

# perform union operation using union()
print('Union using union():', A.union(B))
# Out:
# Union using |: {0, 1, 2, 3, 4, 5}
# Union using union(): {0, 1, 2, 3, 4, 5}

# %% [markdown]
# # Intersection in python
