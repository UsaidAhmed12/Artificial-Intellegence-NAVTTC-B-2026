# %%
id = [1,2,3,4]

# %%
Eng = [70,80,90,60]

# %%
Math = [90,90,80,80]

# %%
Computer = [80,80,90,90]

# %%
for i in range(len(id)):
    total = Eng[i] + Math[i] + Computer[i]
    average =float(total/3)

    print('Id of each student is',id[i])
    print("Total marks obtained",total)
    print("Average of marks is",average
    print("----------------------------")
# Out:
# Id of each student is 1
# Total marks obtained 240
# Average of marks is 80.0
# ----------------------------
# Id of each student is 2
# Total marks obtained 250
# Average of marks is 83.33333333333333
# ----------------------------
# Id of each student is 3
# Total marks obtained 260
# Average of marks is 86.66666666666667
# ----------------------------
# Id of each student is 4
# Total marks obtained 230
# Average of marks is 76.66666666666667
# ----------------------------

# %% [markdown]
# # Python Touple

# %%
numbers = (1, 2, -5)
print(numbers)
# Out:
# (1, 2, -5)

# %% [markdown]
# # Access

# %%
languages = ('Python', 'Swift', 'C++')

# access the first item
print(languages[0])   

# access the third item
print(languages[2])   

print(languages[1])
# Out:
# Python
# C++
# Swift

# %% [markdown]
# # Error because no modification

# %%
cars = ('BMW', 'Tesla', 'Ford', 'Toyota','Civic')

# trying to modify a tuple
cars[0] = 'Nissan'  
cars[1] = 'Alto'
       
print(cars)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 cars = ('BMW', 'Tesla', 'Ford', 'Toyota','Civic')
#       3 # trying to modify a tuple
# ----> 4 cars[0] = 'Nissan'
#       5 cars[1] = 'Alto'
#       7 print(cars)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Length of car

# %%
cars = ('BMW', 'Tesla', 'Ford', 'Toyota')
print('Total Items:', len(cars))
# Out:
# Total Items: 4
